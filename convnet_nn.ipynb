# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Activation
import pickle
import numpy as np

# %%
x = pickle.load(open('data/x.pickle', 'rb'))
y = pickle.load(open('data/y.pickle', 'rb'))

# %%
x = x/255.0

# %%
x.shape
# Out:
# (24997, 50, 50, 1)

# %%
x = np.asarray(x)
y = np.asarray(y)

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), input_shape = x.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

model.fit(x, y, batch_size=32, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.5973 - loss: 0.6629 - val_accuracy: 0.6592 - val_loss: 0.6326
# Epoch 2/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.7310 - loss: 0.5428 - val_accuracy: 0.7024 - val_loss: 0.5939
# Epoch 3/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.7674 - loss: 0.4831 - val_accuracy: 0.7220 - val_loss: 0.5653
# Epoch 4/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.7787 - loss: 0.4692 - val_accuracy: 0.7764 - val_loss: 0.4810
# Epoch 5/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8001 - loss: 0.4335 - val_accuracy: 0.7804 - val_loss: 0.4813
# Epoch 6/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8124 - loss: 0.4110 - val_accuracy: 0.7576 - val_loss: 0.5425
# Epoch 7/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8196 - loss: 0.4026 - val_accuracy: 0.7960 - val_loss: 0.4576
# Epoch 8/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8380 - loss: 0.3655 - val_accuracy: 0.7908 - val_loss: 0.4575
# Epoch 9/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8453 - loss: 0.3472 - val_accuracy: 0.7992 - val_loss: 0.4692
# Epoch 10/10
# 704/704 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.8509 - loss: 0.3394 - val_accuracy: 0.7928 - val_loss: 0.4771
